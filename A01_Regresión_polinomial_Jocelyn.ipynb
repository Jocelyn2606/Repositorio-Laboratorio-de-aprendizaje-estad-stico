# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd

# %% [markdown]
# Para los datos de los archivos "bateria_tableta.txt" y "Salarios_minimos.csv":

# %%
from google.colab import files
uploaded = files.upload()

Salarios_minimos = pd.read_csv("Salarios_minimos.csv")
Salarios_minimos.head()
# Out:
#      <input type="file" id="files-7ff523ec-7c40-4360-89a9-42dd58c63d59" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ff523ec-7c40-4360-89a9-42dd58c63d59">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

bateria = pd.read_csv("bateria_tableta.txt")
bateria.head()
# Out:
#      <input type="file" id="files-e6de4563-ea33-45e4-8aac-8ddec98c8fac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e6de4563-ea33-45e4-8aac-8ddec98c8fac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 1. Realiza regresiones polinomiales de orden 1, 3, 5 y 7.

# %% [markdown]
# # ***Regresió "bateria_tableta"***

# %% [markdown]
# **1er orden**

# %%
x = bateria["carga"].values.reshape(-1, 1)

# %%
y =bateria["duracion"]

# %%
X = x
lr_1 = LinearRegression()
lr_1.fit(X,y)
# Out:
# LinearRegression()

# %%
lr_1.intercept_
# Out:
# np.float64(2.8705411116210198)

# %%
lr_1.coef_
# Out:
# array([0.72955585])

# %% [markdown]
# **r2 grado 1**

# %%
r2 =lr_1.score(X,y)
print("R² grado 1:", r2)
# Out:
# R² grado 1: 0.6872269726243967

# %% [markdown]
# **3er orden**

# %%
x2 = x**2
x3 = x**3

# %%
X3 = np.hstack([x, x2, x3])

# %%
lr_3 = LinearRegression()
lr_3.fit(X3,y)
# Out:
# LinearRegression()

# %%
lr_3.intercept_, lr_3.coef_
# Out:
# (np.float64(-0.8445986553682463),
#  array([ 3.34240792, -0.39326189,  0.01452403]))

# %% [markdown]
# **r2 grado 3**

# %%
r2_3 =lr_3.score(X3,y)
print("R² grado 3:", r2_3)
# Out:
# R² grado 3: 0.9780671146743033

# %% [markdown]
# **5to orden**

# %%
x4 = x**4
x5 = x**5

# %%
X5 = np.hstack([x, x2, x3, x4, x5])

# %%
lr_5 = LinearRegression()
lr_5.fit(X5,y)
# Out:
# LinearRegression()

# %%
lr_5.intercept_, lr_5.coef_
# Out:
# (np.float64(0.14276244863231113),
#  array([ 8.35890085e-01,  1.10347381e+00, -3.23550360e-01,  3.20123836e-02,
#         -1.07054199e-03]))

# %% [markdown]
# **r2 grado 5**

# %%
r2_5 =lr_5.score(X5,y)
print("R² grado 5:", r2_5)
# Out:
# R² grado 5: 0.9953630126134433

# %% [markdown]
# **7timo orden**

# %%
x6 = x**6
x7 = x**7

# %%
X7 = np.hstack([x,x2,x3,x4,x5,x6,x7])

# %%
lr_7 = LinearRegression()
lr_7.fit(X7,y)
# Out:
# LinearRegression()

# %%
lr_7.intercept_, lr_7.coef_
# Out:
# (np.float64(-0.026730011142747756),
#  array([ 2.63586646e+00, -1.38252388e+00,  1.01240187e+00, -3.16715233e-01,
#          4.60134802e-02, -3.15491538e-03,  8.27801489e-05]))

# %% [markdown]
# **r2 grado 7**

# %%
r2_7 =lr_7.score(X7,y)
print("R² grado 1:", r2_7)
# Out:
# R² grado 1: 0.998096560245418

# %% [markdown]
# 2. Compración de R2

# %%
print("R² grado 1:", r2)
print("R² grado 3:", r2_3)
print("R² grado 5:", r2_5)
print("R² grado 7:", r2_7)
# Out:
# R² grado 1: 0.6872269726243967
# R² grado 3: 0.9780671146743033
# R² grado 5: 0.9953630126134433
# R² grado 7: 0.998096560245418

# %% [markdown]
# Como se puede observar, al tener un R2 en un grado mas alto hay un mejora en el ajuste del modelo. El r2 del grado 7 es de 0.99, lo cual significa que este tiene una mejor cercanía a los datos.

# %% [markdown]
# 3. Crea una gráfica con una nube de dispersión (datos originales) y tus modelos

# %%
import matplotlib.pyplot as plt

# %%
x_plot = np.linspace(x.min(), x.max(), 300).reshape(-1,1)

# %%
y1 = lr_1.predict(x_plot)

y3 = lr_3.predict(
    np.hstack([x_plot, x_plot**2, x_plot**3])
)

y5 = lr_5.predict(
    np.hstack([x_plot, x_plot**2, x_plot**3, x_plot**4, x_plot**5])
)

y7 = lr_7.predict(
    np.hstack([x_plot, x_plot**2, x_plot**3, x_plot**4, x_plot**5, x_plot**6, x_plot**7])
)

# %%
plt.scatter(x, y, label="Datos originales")
plt.plot(x_plot, y1, label="Grado 1")
plt.plot(x_plot, y3, label="Grado 3")
plt.plot(x_plot, y5, label="Grado 5")
plt.plot(x_plot, y7, label="Grado 7")
plt.legend()
plt.show()

# %% [markdown]
# # ***Regresión "Salarios_minimos.csv"***

# %% [markdown]
# 1. Realiza regresiones polinomiales de orden 1, 3, 5 y 7.

# %% [markdown]
# **orden 1**

# %%
xs = Salarios_minimos['Periodo'].values.reshape(-1, 1)

# %%
ys = Salarios_minimos['Salario']

# %%
Xs = xs
lrs_1 = LinearRegression()
lrs_1.fit(Xs,ys)
# Out:
# LinearRegression()

# %%
lrs_1.intercept_
# Out:
# np.float64(-5022.60217164143)

# %%
lrs_1.coef_
# Out:
# array([2.52832885])

# %% [markdown]
# **r2 orden 1**

# %%
r2_s_1 =lrs_1.score(Xs,ys)

# %%
r2_s_1
# Out:
# 0.98445666630952

# %% [markdown]
# **orden 3**

# %%
xs_2 = xs**2
xs_3 = xs**3

# %%
Xs_3 = np.hstack([xs, xs_2, xs_3])

# %%
lrs_3 = LinearRegression()
lrs_3.fit(Xs_3,ys)
# Out:
# LinearRegression()

# %%
lrs_3.intercept_, lrs_3.coef_
# Out:
# (np.float64(-5217722.9582693195),
#  array([ 7.83146244e+03, -3.91934110e+00,  6.54024500e-04]))

# %%
r2s_3 =lrs_3.score(Xs_3,ys)
print("R² grado 3:", r2s_3)
# Out:
# R² grado 3: 0.9857366949646496

# %% [markdown]
# **orden 5**

# %%
xs_4 =xs**4
xs_5=xs**5

# %%
Xs_5= np.hstack([xs,xs_2,xs_3,xs_4,xs_5])

# %%
lrs_5 = LinearRegression()
lrs_5.fit(Xs_5,ys)
# Out:
# LinearRegression()

# %%
lrs_5.intercept_, lrs_5.coef_
# Out:
# (np.float64(-534328.7907936319),
#  array([ 3.32926286e-10,  6.66831636e-07,  6.67827159e-04, -5.01138166e-07,
#          1.00311032e-10]))

# %%
r2s_5 =lrs_5.score(Xs_5,ys)
print("R² grado 5:", r2s_5)
# Out:
# R² grado 5: 0.9857546631343813

# %% [markdown]
# **orden 7**

# %%
xs_6 =xs**6
xs_7=xs**7

# %%
Xs_7 = np.hstack([xs,xs_2,xs_3,xs_4,xs_5,xs_6,xs_7])

# %%
lrs_7 = LinearRegression()
lrs_7.fit(Xs_7,ys)
# Out:
# LinearRegression()

# %%
lrs_7.intercept_, lrs_7.coef_
# Out:
# (np.float64(-156804.77949517986),
#  array([ 1.91160388e-23, -1.65984995e-18,  9.20291789e-17,  1.22888842e-13,
#          1.02560834e-10, -8.54813517e-14,  1.83257513e-17]))

# %%
r2s_7 =lrs_7.score(Xs_7,ys)
print("R² grado 7:", r2s_7)
# Out:
# R² grado 7: 0.9857730993924559

# %% [markdown]
# 2. Comparación R2

# %%
print("R² grado 1:", r2_s_1)
print("R² grado 3:", r2s_3)
print("R² grado 5:", r2s_5)
print("R² grado 7:", r2s_7)
# Out:
# R² grado 1: 0.98445666630952
# R² grado 3: 0.9857366949646496
# R² grado 5: 0.9857546631343813
# R² grado 7: 0.9857730993924559

# %% [markdown]
# 3. Crea una gráfica con una nube de dispersión (datos originales) y tus modelos

# %%
xs_plot = np.linspace(xs.min(), xs.max(), 300).reshape(-1,1)

# %%
ys_1 = lrs_1.predict(xs_plot)

ys_3 = lrs_3.predict(
    np.hstack([xs_plot, xs_plot**2, xs_plot**3])
)

ys_5 = lrs_5.predict(
    np.hstack([xs_plot, xs_plot**2, xs_plot**3, xs_plot**4, xs_plot**5])
)

ys_7 = lrs_7.predict(
    np.hstack([xs_plot, xs_plot**2, xs_plot**3, xs_plot**4, xs_plot**5, xs_plot**6, xs_plot**7])
)

# %%
plt.scatter(xs, ys, label="Datos originales")
plt.plot(xs_plot, ys_1, label="Grado 1")
plt.plot(xs_plot, ys_3, label="Grado 3")
plt.plot(xs_plot, ys_5, label="Grado 5")
plt.plot(xs_plot, ys_7, label="Grado 7")
plt.legend()
plt.show()
