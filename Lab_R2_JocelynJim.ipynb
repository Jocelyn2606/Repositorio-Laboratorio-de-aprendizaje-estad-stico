# %% [markdown]
# # Laboratorio de regresión - 2

# %% [markdown]
# |                |   |
# :----------------|---|
# | **Nombre**     |   |
# | **Fecha**      |   |
# | **Expediente** |   |

# %% [markdown]
# ## Regresión polinomial

# %% [markdown]
# Observa la siguiente gráfica.

# %%
import matplotlib.pyplot as plt; import numpy as np
# %matplotlib inline
np.random.seed(0)
x = np.linspace(-3, 3, 100); y = 1 + 4*x**2 + np.random.normal(0, 1, 100)
plt.figure(); plt.xlabel("x"); plt.ylabel("y")
plt.scatter(x, y); plt.grid()

# %% [markdown]
# Utiliza `sklearn` para realizar una regresión lineal simple ($\hat{y} = \hat{\beta_0} + \hat{\beta_1}x $)

# %%
from sklearn.linear_model import LinearRegression

# %%
X = x.reshape(-1,1)
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# Crea una gráfica donde se muestren las observaciones como una nube de puntos y la línea que ajustaste con regresión. Calcula el métrico $R^2$.

# %%
y_pred = lr.predict(X)

# %%
plt.figure()
plt.scatter(x, y, label="Datos")
plt.plot(x, y_pred, color="red", label="LinearRegression")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()

# %%
R2 = lr.score(X,y)
R2
# Out:
# 5.80345273922811e-05

# %% [markdown]
# Podemos ver que el ajuste no es correcto, pues parece que tiene un comportamiento cuadrático y estamos intentando ajustar una línea recta.
#
# En lugar de hacer una regresión lineal simple, quizás podamos extender el modelo para que tenga varios factores dentro:
#
# $$ Y = \beta_0 + \beta_1 X + \beta_2 X^2 + ... + \beta_p X^p + \epsilon$$

# %% [markdown]
# Ajusta un modelo cuadrático con `sklearn` ($\hat{y} = \hat{\beta_0} + \hat{\beta_1}x + \hat{\beta_1}x^2 $) y calcula su $R^2$.

# %%
x2 = x**2

# %%
X2 = np.column_stack([x, x2])

# %%
lr_2 = LinearRegression()
lr_2.fit(X2,y)
# Out:
# LinearRegression()

# %%
R2_2 = lr_2.score(X2,y)
R2_2
# Out:
# 0.9934118040713642

# %%
y_pred_x2 = lr_2.predict(X2)

# %% [markdown]
# Crea una gráfica con las observaciones y la nueva curva que ajustaste.

# %%
plt.figure()
plt.scatter(x, y, label="Datos")
plt.plot(x, y_pred_x2, color="red", label="Regresión cuadrática")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Ajusta modelos de grados 3, 5, 7, 9, y 11. Calcula su $R^2$.

# %% [markdown]
# **Grado 3**

# %%
x3 = x**3

# %%
X3 = np.column_stack([x, x2,x3])

# %%
lr_3 = LinearRegression()
lr_3.fit(X3,y)
# Out:
# LinearRegression()

# %%
R2_3 = lr_3.score(X3,y)
R2_3
# Out:
# 0.9934129585186598

# %%
y_pred_x3 = lr_3.predict(X3)

# %% [markdown]
# **Grado 5**

# %%
x4 = x**4
x5 = x**5

# %%
X5 = np.column_stack([x, x2, x3, x4, x5])

# %%
lr_5 = LinearRegression()
lr_5.fit(X5,y)
# Out:
# LinearRegression()

# %%
R2_5 = lr_5.score(X5,y)
R2_5
# Out:
# 0.9934954953676421

# %%
y_pred_x5 = lr_5.predict(X5)

# %% [markdown]
# **Grado 7**

# %%
x6 = x**6
x7 = x**7

# %%
X7 = np.column_stack([x, x2, x3, x4, x5, x6, x7])

# %%
lr_7 = LinearRegression()
lr_7.fit(X7,y)
# Out:
# LinearRegression()

# %%
R2_7 = lr_7.score(X7,y)
R2_7
# Out:
# 0.9935089341876935

# %%
y_pred_x7 = lr_7.predict(X7)

# %% [markdown]
# **Grado 9**

# %%
x8 = x**8
x9 = x**9

# %%
X9 = np.column_stack([x, x2, x3, x4, x5, x6, x7, x8, x9])

# %%
lr_9 = LinearRegression()
lr_9.fit(X9,y)
# Out:
# LinearRegression()

# %%
R2_9 = lr_9.score(X9,y)
R2_9
# Out:
# 0.9935141799662259

# %%
y_pred_x9 = lr_9.predict(X9)

# %% [markdown]
# **Grado 11*

# %%
x10 = x**10
x11 = x**11

# %%
X11 = np.column_stack([x, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11])

# %%
lr_11 = LinearRegression()
lr_11.fit(X11,y)
# Out:
# LinearRegression()

# %%
R2_11 = lr_11.score(X11,y)
R2_11
# Out:
# 0.9935338704150221

# %%
y_pred_x11 = lr_11.predict(X11)

# %% [markdown]
# Crea una gráfica por cada modelo con las observaciones y su curva.

# %% [markdown]
# **grado 3**

# %%
plt.figure()
plt.scatter(x, y, label="Datos")
plt.plot(x, y_pred_x3, color="red", label="Regresión cuadrática")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Grado 5**

# %%
plt.figure()
plt.scatter(x, y, label="Datos")
plt.plot(x, y_pred_x5, color="red", label="Regresión cuadrática")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Grado 7**

# %%
plt.figure()
plt.scatter(x, y, label="Datos")
plt.plot(x, y_pred_x7, color="red", label="Regresión cuadrática")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Grado 9**

# %%
plt.figure()
plt.scatter(x, y, label="Datos")
plt.plot(x, y_pred_x9, color="red", label="Regresión cuadrática")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Grado 11**

# %%
plt.figure()
plt.scatter(x, y, label="Datos")
plt.plot(x, y_pred_x11, color="red", label="Regresión cuadrática")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **¿Cuál modelo consideras que es mejor? ¿Por qué?**

# %%
R2_results = {"Grado 1": R2, "Grado 2": R2_2, "Grado 3": R2_3, "Grado 5": R2_5, "Grado 7": R2_7, "Grado 9": R2_9, "Grado 11": R2_11 }
R2_results
# Out:
# {'Grado 1': 5.80345273922811e-05,
#  'Grado 2': 0.9934118040713642,
#  'Grado 3': 0.9934129585186598,
#  'Grado 5': 0.9934139577341331,
#  'Grado 7': 0.9935089341876935,
#  'Grado 9': 0.9935141799662259,
#  'Grado 11': 0.9935338704150221}

# %% [markdown]
# El mejor modelo es el polinomial, ya que es el que mejor se ajusta y así se logra obtener un mejor R2. Los resultado de R2 son muy parecidos. Conforme aumenta el grado, el R2 se mantiene.

# %% [markdown]
# Recuerda que una de las metas de ajustar modelos es para poder interpolar y extrapolar. Los datos que tenemos mantienen $x \in [-3, 3]$. ¿Qué pasaría si quisiéramos saber el valor de $y$ cuando $x=5$?
#
# Calcula la predicción $\hat{y}$ para todos los modelos creados (grados 2, 3, 5, 7, 9, y 11).

# %%
x_nueva = 5

# %% [markdown]
# **Grado 2**

# %%
X2_nueva = np.array([[x_nueva, x_nueva**2]])
y_pred_2 = lr_2.predict(X2_nueva)
y_pred_2
# Out:
# array([103.96886955])

# %% [markdown]
# **Grado 3**

# %%
X3_nueva = np.array([[x_nueva, x_nueva**2, x_nueva**3]])
y_pred_3 = lr_3.predict(X3_nueva)
y_pred_3
# Out:
# array([104.25232439])

# %% [markdown]
# **Grado 5**

# %%
X5_nueva = np.array([[x_nueva, x_nueva**2, x_nueva**3, x_nueva**4, x_nueva**5]])
y_pred_5 = lr_5.predict(X5_nueva)
y_pred_5
# Out:
# array([84.59895013])

# %% [markdown]
# **Grado 7**

# %%
X7_nueva = np.array([[x_nueva, x_nueva**2, x_nueva**3, x_nueva**4, x_nueva**5, x_nueva**6, x_nueva**7]])
y_pred_7 = lr_7.predict(X7_nueva)
y_pred_7
# Out:
# array([33.74321848])

# %% [markdown]
# **Grado 9**

# %%
X9_nueva = np.array([[x_nueva, x_nueva**2, x_nueva**3, x_nueva**4, x_nueva**5, x_nueva**6, x_nueva**7, x_nueva**8, x_nueva**9]])
y_pred_9 = lr_9.predict(X9_nueva)
y_pred_9
# Out:
# array([215.73637926])

# %% [markdown]
# **Grado 11**

# %%
X11_nueva = np.array([[x_nueva, x_nueva**2, x_nueva**3, x_nueva**4, x_nueva**5, x_nueva**6, x_nueva**7, x_nueva**8, x_nueva**9, x_nueva**10, x_nueva**11]])
y_pred_11 = lr_11.predict(X11_nueva)
y_pred_11
# Out:
# array([-5265.34425354])

# %% [markdown]
# ¿Cuál modelo crees que sea mejor?

# %%
pred_results = {"Grado 2": y_pred_2, "Grado 3": y_pred_3, "Grado 5": y_pred_5, "Grado 7": y_pred_7, "Grado 9": y_pred_9, "Grado 11": y_pred_11 }
pred_results
# Out:
# {'Grado 2': array([103.96886955]),
#  'Grado 3': array([104.25232439]),
#  'Grado 5': array([84.59895013]),
#  'Grado 7': array([33.74321848]),
#  'Grado 9': array([215.73637926]),
#  'Grado 11': array([-5265.34425354])}

# %% [markdown]
# Al extrapolar la x con un valor de 5, los datos producen predicciones muy diferentes e inestables. Por el otro lado, el modelo cuadrático ofrece un buen ajuste dentro del rango y un comportamiento más estable.

# %% [markdown]
# ## Referencia
#
# James, G., Witten, D., Hastie, T., Tibshirani, R.,, Taylor, J. (2023). An Introduction to Statistical Learning with Applications in Python. Cham: Springer. ISBN: 978-3-031-38746-3
